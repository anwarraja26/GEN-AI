# %%
# !pip install -q pypdf
# !pip install -q docx2txt
# !pip install -q google-generativeai
# !pip install -q transformers
# !pip install -q llama-index

# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, ServiceContext, StorageContext, load_index_from_storage
import os

# %% [markdown]
# ## LOAD DATA

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
documents=SimpleDirectoryReader("data").load_data()

# %%
documents
# Out:
# [Document(id_='6be758d9-25a1-40cf-b9b8-8f70cf875084', embedding=None, metadata={'page_label': '1', 'file_name': 'AI and DS Roadmap.pdf', 'file_path': '/content/data/AI and DS Roadmap.pdf', 'file_type': 'application/pdf', 'file_size': 68154, 'creation_date': '2025-08-03', 'last_modified_date': '2025-08-03'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="AI AND DATA SCIENCE: A BEGINNER'S\nROADMAP\nTHE JOURNEY BEGINS: DEMYSTIFYING AI AND DATA\nSCIENCE\nArtificial Intelligence (AI) is about creating machines that can perform tasks\nthat typically require human intelligence, like learning and problem-solving.\nData Science, on the other han
# ...

# %% [markdown]
# ## Split the Text into Small Chunks

# %%
os.environ['GOOGLE_API_KEY']="AIzaSyB3uCn72QJ-SLI6nKeq-qaEcgSfs9hP9s4"

# %%
# !pip install langchain-google-genai google-generativeai -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.7 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.9)

# %% [markdown]
# ## Here in llama index we use the service context to split as chunks whereas in the langchain we use the text splitter

# %%
from llama_index.core import Settings
from llama_index.llms.langchain import LangChainLLM
from llama_index.embeddings.langchain import LangchainEmbedding

Settings.llm = LangChainLLM(llm=llm)
Settings.embed_model = LangchainEmbedding(embed_model=embed_model)
Settings.chunk_size = 800
Settings.chunk_overlap = 20
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1670428681.py in <cell line: 0>()
#       1 from llama_index.core import Settings
#       2 from llama_index.llms.langchain import LangChainLLM
# ----> 3 from llama_index.embeddings.langchain import LangchainEmbedding
#       4
#       5 Settings.llm = LangChainLLM(llm=llm)
#
# ModuleNotFoundError: No module named 'llama_index.embeddings.langchain'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q llama-index-llms-langchain

# %%
# !pip install -q sentence_transformers
# !pip install -q langchain-community
# !pip install -q llama-index-embeddings-langchain
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 831.2 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 20.7 MB/s eta 0:00:00

# %%
from langchain.embeddings.huggingface import HuggingFaceBgeEmbeddings
embed_model=HuggingFaceBgeEmbeddings(model_name="BAAI/bge-base-en")
# Out:
# /tmp/ipython-input-1689452857.py:2: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embed_model=HuggingFaceBgeEmbeddings(model_name="BAAI/bge-base-en")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
index = VectorStoreIndex.from_documents(documents, show_progress=True)
# Out:
# Parsing nodes:   0%|          | 0/27 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/llama_index/core/embeddings/utils.py in resolve_embed_model(embed_model, callback_manager)
#      58             embed_model = OpenAIEmbedding()
# ---> 59             validate_openai_api_key(embed_model.api_key)  # type: ignore
#      60         except ImportError:
#
# /usr/local/lib/python3.11/dist-packages/llama_index/embeddings/openai/utils.py in validate_openai_api_key(api_key)
#     103     if not openai_api_key:
# --> 104         raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# ...

# %%
# Step 1: Install dependencies (if not already installed)
# !pip install -q pypdf docx2txt google-generativeai transformers llama-index sentence_transformers langchain-community llama-index-llms-langchain llama-index-embeddings-langchain langchain-google-genai

# Step 2: Imports
from llama_index.core import SimpleDirectoryReader, StorageContext, load_index_from_storage
from llama_index.core import VectorStoreIndex
from langchain.embeddings.huggingface import HuggingFaceBgeEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from llama_index.llms.langchain import LangChainLLM
from llama_index.embeddings.langchain import LangchainEmbedding
from llama_index.core import Settings

import os

# Step 3: Load data
# !mkdir -p data
documents = SimpleDirectoryReader("data").load_data()

# Step 4: Set Gemini LLM
os.environ['GOOGLE_API_KEY'] = "AIzaSyB3uCn72QJ-SLI6nKeq-qaEcgSfs9hP9s4"
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.9)

# Step 5: Set Embedding model
embed_model = HuggingFaceBgeEmbeddings(model_name="BAAI/bge-base-en")

# Step 6: Configure LlamaIndex Settings
Settings.llm = LangChainLLM(llm=llm)
Settings.embed_model = LangchainEmbedding(embed_model)

Settings.chunk_size = 800
Settings.chunk_overlap = 20

# Step 7: Create the index
index = VectorStoreIndex.from_documents(documents, show_progress=True)
# Out:
# ...
# Generating embeddings:   0%|          | 0/27 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %% [markdown]
# ## Storing and loading the index

# %%
index.storage_context.persist()

# %% [markdown]
# ## LOADING THE ALREADY CREATED INDEX CODE

# %%
storage_context=StorageContext.from_defaults(persist_dir="./storage")
index=load_index_from_storage(storage_context=storage_context)
# Out:
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/index_store.json.

# %% [markdown]
# #Q/A

# %%
query_engine=index.as_query_engine()

# %%
response=query_engine.query("what is road for ai")
response
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ...

# %%
from IPython.display import Markdown, display
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The provided text describes a roadmap for learning artificial intelligence (AI) and data science.  It emphasizes that mastering these fields is a continuous journey requiring curiosity and perseverance.  The roadmap suggests building a foundation in programming (specifically Python), and seeking mentorship.  It also recommends following prominent researchers and organizations on social media.</b>

# %%
response=query_engine.query("what is llama index")
display(Markdown(f"<b>{response}</b>"))
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# <b>This question cannot be answered from the given source.  The provided text focuses on regression and classification techniques, bias in AI, fairness, transparency, and advanced AI topics, but it does not mention Llama Index.</b>
